# %%
import numpy as np
import pandas as pd

df = pd.read_csv(r"C:\Users\vinui\OneDrive\Desktop\Project\data\raw\NBASeasonData.csv")
df
# Out:
#       Year   Tm              Player  Age  Games    MP  PER     TS%   3PAr  \
# 0     2011  GSW         Monta Ellis   25     80  3227  18.6  0.536  0.235
# 1     2011  POR   LaMarcus Aldridge   25     81  3211  21.5  0.549  0.016
# 2     2011  CHI           Luol Deng   25     82  3208  15.5  0.549  0.288
# 3     2011  GSW       Dorell Wright   25     82  3147  15.0  0.539  0.450
# 4     2011  LAC       Blake Griffin   21     82  3112  21.9  0.549  0.017
# ...    ...  ...                 ...  ...    ...   ...   ...    ...    ...
# 3101  2016  ATL      Walter Tavares   23      2     2  24.5  0.568  0.000
# 3102  2016  IND  Shayne Whittington   24      1     2 -64.6  0.000  0.000
# 3103  2016  IND        Solomon Hill   24      1     2   0.0  0.000  0.000
# 3104  2016  UTA         Jeff Withey   25      1     1   0.0  0.000  0.000
# 3105  2016  CHI   Cristiano Felicio   23      1     1  35.3  0.000  0.000
#
#         FTr  ORB%  DRB%  TRB%   AST%  STL%  BLK%   TOV%
# ...
